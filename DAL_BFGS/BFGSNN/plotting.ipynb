# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/linear/results/AONN/ABt1m1/expInfo.json",'rb') as f:
    info_ab = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/linear/results/AONN/ABt1m2/expInfo.json",'rb') as f:
    info_ab2 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/linear/results/AONN/At1/expInfo.json",'rb') as f:
    info_a = json.load(f)

# %%
info_ab.keys()
# Out:
# dict_keys(['dataname', 'expname', 'bw', 'out_iter', 'inner_iter', 'stepsize', 'decay_rate', 'memory', 'timelist', 'vylist', 'vulist', 'curvcon', 'walltime', 'endouteriter', 'lastvy', 'lastvu'])

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_a['vulist'],linewidth = 3)
plt.plot(info_ab['vulist'],linewidth=3)
plt.plot(info_ab2['vulist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','BFGS_m1','BFGS_m2'],fontsize=30,loc='upper right')
plt.savefig("figures/linear.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
#plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_a['timelist'],linewidth = 3)
plt.plot(info_ab['timelist'],linewidth=3)
plt.plot(info_ab2['timelist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','BFGS_m1','BFGS_m2'],fontsize=30,loc='upper left')
plt.savefig("figures/linear_time.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
#plt.plot(info_a['timelist'],linewidth = 3)
plt.plot(info_ab['curvcon'],linewidth=3)
plt.plot(info_ab2['curvcon'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['BFGS_m1','BFGS_m2'],fontsize=30,loc='upper right')
plt.savefig("figures/linear_curvcon.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/linear_ctd/results/AONN/ABt1m1/expInfo.json",'rb') as f:
    info_ab = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/linear_ctd/results/AONN/At1/expInfo.json",'rb') as f:
    info_a = json.load(f)

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_a['vulist'],linewidth = 3)
plt.plot(info_ab['vulist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','BFGS_m1'],fontsize=30,loc='upper right')
plt.savefig("figures/linear_ctd.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
#plt.plot(info['vylist'])
plt.plot(info_a['timelist'],linewidth = 3)
plt.plot(info_ab['timelist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','BFGS_m1'],fontsize=30,loc='upper left')
plt.savefig("figures/linear_ctd_time.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/semilinear/results/AONN/ABt1/expInfo.json",'rb') as f:
    info_ab = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/semilinear/results/AONN/ABt1m2/expInfo.json",'rb') as f:
    info_ab2 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/semilinear/results/AONN/ABt1m3/expInfo.json",'rb') as f:
    info_ab3 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/semilinear/results/AONN/ABt1m4/expInfo.json",'rb') as f:
    info_ab4 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/semilinear/results/AONN/ABt1m10/expInfo.json",'rb') as f:
    info_ab10 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/semilinear/results/AONN/At1/expInfo.json",'rb') as f:
    info_a = json.load(f)

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_a['vulist'],linewidth = 3)
plt.plot(info_ab['vulist'],linewidth=3)
plt.plot(info_ab2['vulist'],linewidth=3)
plt.plot(info_ab3['vulist'],linewidth=3)
plt.plot(info_ab4['vulist'],linewidth=3)
plt.plot(info_ab10['vulist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','BFGS_m1','BFGS_m2','BFGS_m3','BFGS_m4','BFGS_m10'],fontsize=20,loc='upper right')
plt.savefig("figures/semilinear.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
#plt.plot(info['vylist'])
plt.plot(info_a['timelist'],linewidth = 3)
plt.plot(info_ab['timelist'],linewidth=3)
plt.plot(info_ab2['timelist'],linewidth=3)
plt.plot(info_ab3['timelist'],linewidth=3)
plt.plot(info_ab4['timelist'],linewidth=3)
plt.plot(info_ab10['timelist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','BFGS_m1','BFGS_m2','BFGS_m3','BFGS_m4','BFGS_m10'],fontsize=20,loc='upper left')
plt.savefig("figures/semilinear_time.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_ab['curvcon'],linewidth=3)
plt.plot(info_ab2['curvcon'],linewidth=3)
plt.plot(info_ab3['curvcon'],linewidth=3)
plt.plot(info_ab4['curvcon'],linewidth=3)
plt.plot(info_ab10['curvcon'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['BFGS_m1','BFGS_m2','BFGS_m3','BFGS_m4','BFGS_m10'],fontsize=20,loc='upper right')
plt.savefig("figures/semilinear_curvcon.png",dpi=400,bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 4
#       2 plt.yscale('log')
#       3 #plt.plot(info['vylist'])
# ----> 4 plt.plot(info_ab['curvcon'],linewidth=3)
#       5 plt.plot(info_ab2['curvcon'],linewidth=3)
#       6 plt.plot(info_ab3['curvcon'],linewidth=3)
#
# KeyError: 'curvcon'

# %%
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN_BFGS/ABt1mu1/expInfo.json",'rb') as f:
    info_ab = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN_BFGS/ABt1mu1m2/expInfo.json",'rb') as f:
    info_ab2 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN_BFGS/ABt1mu1m3/expInfo.json",'rb') as f:
    info_ab3 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN_BFGS/ABt1mu1m4/expInfo.json",'rb') as f:
    info_ab4 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN_BFGS/ABt1mu1m10/expInfo.json",'rb') as f:
    info_ab10 = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN/At1/expInfo.json",'rb') as f:
    info_a = json.load(f)
with open("/Users/dual/Documents/projects/DAL_BFGS/BFGSNN/steady_NS/results/AONN/At4/expInfo.json",'rb') as f:
    info_a4 = json.load(f)

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_a['vulist'],linewidth = 3)
plt.plot(info_a4['vulist'],linewidth = 3)
plt.plot(info_ab['vulist'],linewidth=3)
plt.plot(info_ab2['vulist'],linewidth=3)
plt.plot(info_ab3['vulist'],linewidth=3)
plt.plot(info_ab4['vulist'],linewidth=3)
plt.plot(info_ab10['vulist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','DAL_t2','BFGS_m1','BFGS_m2','BFGS_m3','BFGS_m4','BFGS_m10'],fontsize=20,loc='upper right')
plt.savefig("figures/steadyNS.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
#plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_a['timelist'],linewidth = 3)
plt.plot(info_a4['timelist'],linewidth = 3)
plt.plot(info_ab['timelist'],linewidth=3)
plt.plot(info_ab2['timelist'],linewidth=3)
plt.plot(info_ab3['timelist'],linewidth=3)
plt.plot(info_ab4['timelist'],linewidth=3)
plt.plot(info_ab10['timelist'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['DAL','DAL_t2','BFGS_m1','BFGS_m2','BFGS_m3','BFGS_m4','BFGS_m10'],fontsize=20,loc='upper right')
plt.savefig("figures/steadyNS_time.png",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=[10,8])
plt.yscale('log')
#plt.plot(info['vylist'])
plt.plot(info_ab['curvcon'],linewidth=3)
plt.plot(info_ab2['curvcon'],linewidth=3)
plt.plot(info_ab3['curvcon'],linewidth=3)
plt.plot(info_ab4['curvcon'],linewidth=3)
plt.plot(info_ab10['curvcon'],linewidth=3)
plt.grid()
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.legend(['BFGS_m1','BFGS_m2','BFGS_m3','BFGS_m4','BFGS_m10'],fontsize=20,loc='upper right')
plt.savefig("figures/steady_NS_curvcon.png",dpi=400,bbox_inches="tight")
plt.show()
